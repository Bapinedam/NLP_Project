# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from unidecode import unidecode
import spacy
import spacy_spanish_lemmatizer
from sklearn.feature_extraction.text  import TfidfVectorizer
from sklearn.cluster import KMeans
stopwords_sp = stopwords.words('spanish')
nlp = spacy.load("es_core_news_sm")

# %%
Base = pd.read_excel('SUPERVISADO.xlsx',header=0)
Base.tail(1)
# Out:
#          OPE        nivel                        req_estudio_req_experiencia  \
# 4142  112909  Asistencial  Estudio: Diploma de Bachiller  y curso de técn...
#
#                                               proposito  \
# 4142  Realizar labores de apoyo a los procesos del á...
#
#                                               funciones
# 4142  1. Apoyar la gestión documental del Fondo Depa...

# %%
# longitud de terminos en el corpus de cada criterio
temp= []

for i in Base['req_estudio_req_experiencia']:
    temp.append(len (i.split()))

Base['reqcount']=temp

temp1= []

for i in Base['proposito']:
    temp1.append(len (i.split()))

Base['prop_clcount']=temp1

temp2= []

for i in Base['funciones']:
    temp2.append(len (i.split()))

Base['fx_clcount']=temp2
Base
# Out:
#          OPE        nivel                        req_estudio_req_experiencia  \
# 0        785       Asesor  Estudio: Título profesional en disciplina acad...
# 1        788       Asesor  Estudio: Título de formación profesional en nú...
# 2        789       Asesor  Estudio: Título profesional en núcleo básico d...
# 3        790       Asesor  Estudio: Título de formación profesional en di...
# 4        791       Asesor  Estudio: Título de Formación  Profesional en n...
# ...      ...          ...                                                ...
# 4138  110944  Profesional  Estudio: Título profesional en disciplina acad...
# 4139  111001  Asistencial  Estudio: Titulo de bachiller en cualquier moda...
# 4140  111006  Asistencial  Estudio: Titulo de bachiller en cualquier moda...
# 4141  112643      Tecnico  Estudio: Terminación y aprobación de tres (3) ...
# 4142  112909  Asistencial  Estudio: Diploma de Bachiller  y curso de técn...
#
#                                               proposito  \
# 0     Dirigir la formulación y ejecución de planes, ...
# 1     Asesorar a la Secretaría de Agricultura, Ganad...
# 2     Asesorar al Secretario de Hacienda en temas re...
# 3     Asesorar los planes, programas y proyectos de ...
# 4     Asesorar los procesos Administrativos y  Finan...
# ...                                                 ...
# 4138  Agilizar y garantizar eficiencia en los proces...
# 4139  Realizar actividades de apoyo a procesos admin...
# 4140  Realizar actividades de apoyo a los procesos a...
# 4141  Velar por el orden del flujo vehicular en las ...
# 4142  Realizar labores de apoyo a los procesos del á...
#
#                                               funciones  reqcount  \
# 0     1. Asesorar al alcalde, a las dependencias del...        41
# 1     1. Asesorar en la elaboración de los estudios ...        57
# 2     1. Asesorar a la Secretaría de Hacienda, en te...        54
# 3     1. Asesorar a la Secretaría de Salud en el ámb...        61
# 4     1. Asesorar al Despacho del Secretario de Salu...        55
# ...                                                 ...       ...
# 4138  1. Realizar el proceso completo de contratació...        42
# 4139  4. Atender y orientar al público personal y te...        13
# 4140  1. Elaborar bases de datos que se requieran po...        13
# 4141  1. Ejercer control y vigilancia en el cumplimi...        17
# 4142  1. Apoyar la gestión documental del Fondo Depa...        17
#
#       prop_clcount  fx_clcount
# 0               49         230
# 1               42         180
# 2               31         216
# 3               29         201
# 4               25         280
# ...            ...         ...
# 4138            17         260
# 4139            25         110
# 4140            26         112
# 4141            34         300
# 4142            17         164
#
# [4143 rows x 8 columns]

# %%
def pre_procesado(texto):
    texto = texto.lower()
    texto = re.sub(r"[\W\d_]+", " ", texto)
    texto= unidecode(texto)
    texto = texto.split() # tokenización 
    texto = [palabra for palabra in texto if palabra not in stopwords_sp]
    texto=nlp(str(texto))
    text=[]
    for token in texto:        
        text.append(token.lemma_)
    texto = " ".join(text)
    return texto

# %%
# %%time
#Limpieza y stopwords requisitos de estudio y experiencia
Base['req_cl']= Base['req_estudio_req_experiencia'].apply(lambda val: pre_procesado(val))
#Limpieza y stopwords proposito
Base['prop_cl']= Base['proposito'].apply(lambda val: pre_procesado(val))
#Limpieza y stopwords funciones 
Base['fx_cl']= Base['funciones'].apply(lambda val: pre_procesado(val))
# Out:
# Wall time: 8min 28s

# %%
Base['Contenido_cl']= Base['req_cl']+ Base['prop_cl']+ Base['fx_cl']
Base
# Out:
#          OPE        nivel                        req_estudio_req_experiencia  \
# 0        785       Asesor  Estudio: Título profesional en disciplina acad...
# 1        788       Asesor  Estudio: Título de formación profesional en nú...
# 2        789       Asesor  Estudio: Título profesional en núcleo básico d...
# 3        790       Asesor  Estudio: Título de formación profesional en di...
# 4        791       Asesor  Estudio: Título de Formación  Profesional en n...
# ...      ...          ...                                                ...
# 4138  110944  Profesional  Estudio: Título profesional en disciplina acad...
# 4139  111001  Asistencial  Estudio: Titulo de bachiller en cualquier moda...
# 4140  111006  Asistencial  Estudio: Titulo de bachiller en cualquier moda...
# 4141  112643      Tecnico  Estudio: Terminación y aprobación de tres (3) ...
# 4142  112909  Asistencial  Estudio: Diploma de Bachiller  y curso de técn...
#
#                                               proposito  \
# 0     Dirigir la formulación y ejecución de planes, ...
# 1     Asesorar a la Secretaría de Agricultura, Ganad...
# 2     Asesorar al Secretario de Hacienda en temas re...
# 3     Asesorar los planes, programas y proyectos de ...
# 4     Asesorar los procesos Administrativos y  Finan...
# ...                                                 ...
# 4138  Agilizar y garantizar eficiencia en los proces...
# 4139  Realizar actividades de apoyo a procesos admin...
# 4140  Realizar actividades de apoyo a los procesos a...
# 4141  Velar por el orden del flujo vehicular en las ...
# 4142  Realizar labores de apoyo a los procesos del á...
#
#                                               funciones  reqcount  \
# 0     1. Asesorar al alcalde, a las dependencias del...        41
# 1     1. Asesorar en la elaboración de los estudios ...        57
# 2     1. Asesorar a la Secretaría de Hacienda, en te...        54
# 3     1. Asesorar a la Secretaría de Salud en el ámb...        61
# 4     1. Asesorar al Despacho del Secretario de Salu...        55
# ...                                                 ...       ...
# 4138  1. Realizar el proceso completo de contratació...        42
# 4139  4. Atender y orientar al público personal y te...        13
# 4140  1. Elaborar bases de datos que se requieran po...        13
# 4141  1. Ejercer control y vigilancia en el cumplimi...        17
# 4142  1. Apoyar la gestión documental del Fondo Depa...        17
#
#       prop_clcount  fx_clcount  \
# 0               49         230
# 1               42         180
# 2               31         216
# 3               29         201
# 4               25         280
# ...            ...         ...
# 4138            17         260
# 4139            25         110
# 4140            26         112
# 4141            34         300
# 4142            17         164
#
#                                                  req_cl  \
# 0     [ ' estudio ' , ' titulo ' , ' profesional ' ,...
# 1     [ ' estudio ' , ' titulo ' , ' formacion ' , '...
# 2     [ ' estudio ' , ' titulo ' , ' profesional ' ,...
# 3     [ ' estudio ' , ' titulo ' , ' formacion ' , '...
# 4     [ ' estudio ' , ' titulo ' , ' formacion ' , '...
# ...                                                 ...
# 4138  [ ' estudio ' , ' titulo ' , ' profesional ' ,...
# 4139  [ ' estudio ' , ' titulo ' , ' bachiller ' , '...
# 4140  [ ' estudio ' , ' titulo ' , ' bachiller ' , '...
# 4141  [ ' estudio ' , ' terminacion ' , ' aprobacion...
# 4142  [ ' estudio ' , ' diploma ' , ' bachiller ' , ...
#
#                                                 prop_cl  \
# 0     [ ' dirigir ' , ' formulacion ' , ' ejecucion ...
# 1     [ ' asesorar ' , ' secretaria ' , ' agricultur...
# 2     [ ' asesorar ' , ' secretario ' , ' hacienda '...
# 3     [ ' asesorar ' , ' plan ' , ' programa ' , ' p...
# 4     [ ' asesorar ' , ' proceso ' , ' administrativ...
# ...                                                 ...
# 4138  [ ' agilizar ' , ' garantizar ' , ' eficiencia...
# 4139  [ ' realizar ' , ' actividad ' , ' apoyo ' , '...
# 4140  [ ' realizar ' , ' actividad ' , ' apoyo ' , '...
# 4141  [ ' velar ' , ' orden ' , ' flujo ' , ' vehicu...
# 4142  [ ' realizar ' , ' labor ' , ' apoyo ' , ' pro...
#
#                                                   fx_cl  \
# 0     [ ' asesorar ' , ' alcalde ' , ' dependencia '...
# 1     [ ' asesorar ' , ' elaboracion ' , ' estudio '...
# 2     [ ' asesorar ' , ' secretaria ' , ' hacienda '...
# 3     [ ' asesorar ' , ' secretaria ' , ' salud ' , ...
# 4     [ ' asesorar ' , ' despacho ' , ' secretario '...
# ...                                                 ...
# 4138  [ ' realizar ' , ' proceso ' , ' completo ' , ...
# 4139  [ ' atender ' , ' orientar ' , ' publico ' , '...
# 4140  [ ' elaborar ' , ' base ' , ' dato ' , ' reque...
# 4141  [ ' ejercer ' , ' control ' , ' vigilancia ' ,...
# 4142  [ ' apoyar ' , ' gestion ' , ' documental ' , ...
#
#                                            Contenido_cl
# 0     [ ' estudio ' , ' titulo ' , ' profesional ' ,...
# 1     [ ' estudio ' , ' titulo ' , ' formacion ' , '...
# 2     [ ' estudio ' , ' titulo ' , ' profesional ' ,...
# 3     [ ' estudio ' , ' titulo ' , ' formacion ' , '...
# 4     [ ' estudio ' , ' titulo ' , ' formacion ' , '...
# ...                                                 ...
# 4138  [ ' estudio ' , ' titulo ' , ' profesional ' ,...
# 4139  [ ' estudio ' , ' titulo ' , ' bachiller ' , '...
# 4140  [ ' estudio ' , ' titulo ' , ' bachiller ' , '...
# 4141  [ ' estudio ' , ' terminacion ' , ' aprobacion...
# 4142  [ ' estudio ' , ' diploma ' , ' bachiller ' , ...
#
# [4143 rows x 12 columns]

# %%
Asesor=Base[Base['nivel']=='Asesor']
Profesional=Base[Base['nivel']=='Profesional']
Tecnico=Base[Base['nivel']=='Tecnico']
Asistencial=Base[Base['nivel']=='Asistencial']

# %%
# %%time
#vectorización TF-IDF
tfidf_vectorizer = TfidfVectorizer()
#nivel asesor
Asesor_con_cl_tfidf = tfidf_vectorizer.fit_transform(Asesor['Contenido_cl'])
#nivel profesional
Profesional_con_cl_tfidf = tfidf_vectorizer.fit_transform(Profesional['Contenido_cl'])
#nivel técnico
Tecnico_con_cl_tfidf = tfidf_vectorizer.fit_transform(Tecnico['Contenido_cl'])
#nivel asistencial
Asistencial_con_cl_tfidf = tfidf_vectorizer.fit_transform(Asistencial['Contenido_cl'])
# Out:
# Wall time: 917 ms

# %%
# K-Means con el numero de clusters del modelo manual
Askmeans = KMeans(n_clusters=7).fit(Asesor_con_cl_tfidf)
Prokmeans = KMeans(n_clusters=84).fit(Profesional_con_cl_tfidf)
Teckmeans = KMeans(n_clusters=54).fit(Tecnico_con_cl_tfidf)
Akmeans = KMeans(n_clusters=37).fit(Asistencial_con_cl_tfidf)

# %% [markdown]
# Usar gap y silhoutte para determinar el número de cluster sugeridos.
# Probar PCA para reducir la información
# Corregir el tamaño de prueba y los casos para el test (training y test)
# Investigar sobre _mini batch k-means_
